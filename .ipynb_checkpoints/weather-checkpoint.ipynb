# %% [markdown]
# # Displaying Data from [Ilmatieteen laitos](https://www.ilmatieteenlaitos.fi/latauspalvelun-pikaohje)
#
# Processing the data
#
# 1. Loading data into a DataFrame from url taking into account the column separator **','** and decimal separator **'.'**
# 2. deleting column **'snow depth, cm'**
# 3. The first column of the data shows the time in the form:
# > year-month-day hours:minutes:seconds.
# 4. Using all the fields in the time column (date and time), created a column **'aika, s'** in the new DataFrame indicating the time in seconds since the first measurement was taken.
# 5. Added the column **'Air temperature, degC'** to the new DataFrame.
#
# ## Data Visualization
#
# In the graph:
#
# - Time from column **'aika, s'** is shown on the *horizontal axis*.
# - Air temperature from column **'Air temperature, degC'** is shown on the *vertical axis*.
# - Data points are marked with a red dot.
# - The data point with the red dot is marked with a legend that reads **'ilman lämpötila'**.
# - The *horizontal axis* is titled **'aika, s'**, and the *vertical axis* is titled **'ilman lämpötila 𝑜𝐶'**.
# - A grid with a black dashed line is added to the graph.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

url = 'https://raw.githubusercontent.com/WiljamiT/data-visualization/main/csv/saatiedot.csv'
df = pd.read_csv(url, sep=',', decimal='.')

df.drop(columns=['Snow depth, cm'], inplace=True)

df.head()
# Out:
#             Unnamed: 0  Air temperature, degC  Wind speed, m/s  \
# 0  2020-11-04 13:20:00                    6.5              2.3
# 1  2020-11-04 13:30:00                    6.2              2.5
# 2  2020-11-04 13:40:00                    5.7              2.3
# 3  2020-11-04 13:50:00                    5.7              2.8
# 4  2020-11-04 14:00:00                    5.7              3.1
#
#    Gust speed, m/s  Wind direction, deg  Relative humidity, %  \
# 0              4.3                187.0                  79.0
# 1              3.9                180.0                  80.0
# 2              3.5                173.0                  81.0
# 3              4.0                164.0                  81.0
# 4              4.2                164.0                  83.0
#
#    Dew-point temperature, degC  Pressure (msl), hPa  Horizontal visibility, m  \
# 0                          3.1               1011.3                   51434.0
# ...

# %%
time_column = df.columns[0]  
df[time_column] = pd.to_datetime(df[time_column], format='%Y-%m-%d %H:%M:%S')

df['aika, s'] = (df[time_column] - df[time_column][0]).dt.total_seconds()

new_df = df[['aika, s', 'Air temperature, degC']]

print(new_df.head())
# Out:
#    aika, s  Air temperature, degC
# 0      0.0                    6.5
# 1    600.0                    6.2
# 2   1200.0                    5.7
# 3   1800.0                    5.7
# 4   2400.0                    5.7

# %%
plt.figure(figsize=(10, 6))
plt.plot(new_df['aika, s'], new_df['Air temperature, degC'], 'ro', label='ilman lämpötila')
plt.xlabel('aika, s')
plt.ylabel('ilman lämpötila $^\circ$C')
plt.legend()
plt.grid(True, linestyle='--', color='black')
plt.show()

# %% [markdown]
# # Next figure
#
# 1. Loading data into a DataFrame from url taking into account the column separator **','** and decimal separator **'.'**
# 2. deleting column **'snow depth, cm'**
# 3. The first column of the data shows the time in the form:
# > year-month-day hours:minutes:seconds.
# 4. Using all the fields in the time column (date and time), created a column **'time, s'** in the new DataFrame indicating the time in seconds since the first measurement was taken.
# 5. Added the columns **'Air temperature, degC'** and **'Wind speed, m/s'** to the new DataFrame
#
# In the graph:
#
# - Time from the column **'aika, s'** is shown on the *horizontal axis* and air temperature from the column **'Air temperature, degC'** is shown on the left *vertical axis* and wind speed from the column **'Wind speed, m/s'** is shown on the right *vertical axis*
# - In the graph above, data points **('aika, s', 'Air temperature, degC')** are marked with a red dot and data points **('aika, s', 'Wind speed, m/s')** are marked with a blue dot
# - The legend **'ilman lämpötila'** for the data points **('aika, s', 'Air temperature, degC')** is shown in the bottom right of the figure
# - The legend **'tuulen nopeus'** for the data points **('aika, s', 'Wind speed, m/s')** is shown in the upper left of the figure
# - The **x-axis** shows time in units of **⋅10^3s** and the x-axis is headed **'Time, ⋅10^3s'**
# - The y-axis on the left is headed **'ilman lämpötila, 𝑜𝐶'**
# - The right-hand y-axis is headed **'tuulen nopeus, m/s'**
# - Grid with a black dashed line to the graph
# - Background colour (RGB) of the image: '#D7F8FF'
# - Title of the image: **'Säätila Jyväskylän lentoasemalla'**.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

url = 'https://raw.githubusercontent.com/WiljamiT/data-visualization/main/csv/saatiedot.csv'
df = pd.read_csv(url, sep=',', decimal='.')

time_column = df.columns[0]
df[time_column] = pd.to_datetime(df[time_column], format='%Y-%m-%d %H:%M:%S')

df['aika, s'] = (df[time_column] - df[time_column][0]).dt.total_seconds()

new_df = df[['aika, s', 'Air temperature, degC', 'Wind speed, m/s']]

print(new_df.head())
# Out:
#    aika, s  Air temperature, degC  Wind speed, m/s
# 0      0.0                    6.5              2.3
# 1    600.0                    6.2              2.5
# 2   1200.0                    5.7              2.3
# 3   1800.0                    5.7              2.8
# 4   2400.0                    5.7              3.1

# %%
fig, ax1 = plt.subplots()

ax1.set_xlabel('aika, $\\times 10^3$ s')
ax1.set_ylabel('ilman lämpötila, $^\circ$C', color='tab:red')
ax1.plot(new_df['aika, s'] / 1000, new_df['Air temperature, degC'], 'ro', label='ilman lämpötila')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax2 = ax1.twinx()
ax2.set_ylabel('tuulen nopeus, m/s', color='tab:blue')
ax2.plot(new_df['aika, s'] / 1000, new_df['Wind speed, m/s'], 'b.', label='tuulen nopeus')
ax2.tick_params(axis='y', labelcolor='tab:blue')

ax1.legend(loc='lower right')
ax2.legend(loc='upper left')

plt.grid(True, linestyle='--', color='black')
plt.gca().set_facecolor('#D7F8FF')
plt.title('Säätila Jyväskylän lentoasemalla')
plt.show()
